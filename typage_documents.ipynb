# %%
dir_f="C:/Users/Yasmine/Downloads/Handwriting_detection/Documents"
documents= []
for current_dir, dir_names,file_names in os.walk(dir_f):
    for file_name in file_names:
        documents.append(file_name)

# %%
import easyocr
reader = easyocr.Reader(['fr'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
# show an image
import PIL
from PIL import ImageDraw
for doc in documents :
    path='C:/Users/Yasmine/Downloads/Handwriting_detection/Documents/'+doc
    im = PIL.Image.open(path)
    im
    # Doing OCR. Get bounding boxes.
    result= reader.readtext(path)
    for (bbox, text, prob) in result:
        if (text=="Chèque"):
            path1='C:/Users/Yasmine/Downloads/Handwriting_detection/Documents/01'+str(i)+
            if()
            else:
                os.mkdir('C:/Users/Yasmine/Downloads/Handwriting_detection/Documents/'+)

# %%
# show an image
import PIL
from PIL import ImageDraw
path='C:/Users/Yasmine/Downloads/Handwriting_detection/Documents/'+
im = PIL.Image.open(path)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x525 at 0x27CFDB40CC8>

# %%
# Doing OCR. Get bounding boxes.
bounds = reader.readtext(path)
#bounds

# %%
for (bbox, text, prob) in bounds:
    print(text)
# Out:
# isPy B1 bi
# Be0
# 40d Boc
# ChcqueN'
# 2571693
# ATB   Mrah Tuninian IBank
# PayeZCCrcecheoenoenuele
# 4 , 004>
# Soutau Fqi dune Donque Wu dun crgoni:ne Orrimnils
# Yafne
# cqut olncizes;=2
# Afordre de
# Enic Datout
# Pafce
# Tiulipedcve
# 54e)
# LAvarsa
# 01 005 0341105002820 23
# PACE DU 7 MOVEMBRE
# SOCIETE WALLYS CAR
# I6i : 7174371
# Tzss
# {Ulosfa
# LE
# 2200*2571693101005003211050u2820284

# %%
import cv2
# Draw bounding boxes
def draw_boxes(path, bounds, color='yellow', width=2):
    j=0
    image=PIL.Image.open(path)
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        x=p0[0]
        y=p0[1]
        w=p2[0]-x
        h=p2[1]-y
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
        im=cv2.imread(path)
        roi=im[y:y+h,x:x+w]
        cv2.imwrite("/content/drive/MyDrive/Colab Notebooks/segmented_img/image"+str(j)+".png",roi)
        j=j+1
    return image

draw_boxes(path, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x525 at 0x27CA8BEBE08>
